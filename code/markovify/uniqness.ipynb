# %%
import markovify
from tqdm import tqdm
from random import randint
from sklearn.model_selection import train_test_split
import evaluate

# %%
with open("./lotr.txt", "r", encoding='utf-8') as file:
    text = file.read()

data = markovify.Text(text).parsed_sentences

train, test = train_test_split(data, train_size=0.9)
train_text = " ".join([" ".join(sts) for sts in train])

print(f"Length of traingin text: {len(train_text)}")   
print(f"Sentences:\n    In train: {len(train)}\n    In test:  {len(test)}")

models = [None, None]
MIN_SIZE = 2
MAX_SIZE = 5

for size in tqdm(range(MIN_SIZE, MAX_SIZE + 1)):
    models.append(markovify.Text(train_text, state_size=size))
# Out:
# Length of traingin text: 1908131
# Sentences:
#     In train: 22460
#     In test:  2496
# 100%|██████████| 4/4 [00:03<00:00,  1.19it/s]

# %%
def get_uniqness_measure(sentence, n=5): # number of different n-grams
    ngrams = [sentence[i:i+n] for i in range(len(sentence)-n+1)]
    return len(set(ngrams)) / len(ngrams)

# %%
MAX_GENERATIONS_ATTEMPTS = 10

results = [[], []]
references = [[], []]

for size in range(MIN_SIZE, MAX_SIZE + 1):
    print(f"====================== Chain size: {size} ======================")
    results.append([])
    references.append([])
    for ref in tqdm(test):
        if len(ref) < 2:
            continue
        for _ in range(MAX_GENERATIONS_ATTEMPTS):
            try:
                sentence = models[size].make_sentence_with_start(f"{ref[0]} {ref[1]}")
                if sentence:
                    results[size].append(sentence)
                    references[size].append(" ".join(ref))
                break
            except:
                continue
    
    scores = []

    for (ref, result) in tqdm(list(zip(references[size], results[size]))):
        scores.append(get_uniqness_measure(result) / get_uniqness_measure(ref))
    
    # mean 
    score = sum(scores) / len(scores)
    
    print(f"Successful generations: {len(results[-1])}")
    print(f"Uniqness score: {score}")
# Out:
# ====================== Chain size: 2 ======================
# 100%|██████████| 2496/2496 [00:11<00:00, 224.30it/s]
# 100%|██████████| 1635/1635 [00:00<00:00, 39279.93it/s]
# Successful generations: 1635
# Uniqness score: 1.0040521361246943
# ====================== Chain size: 3 ======================
# 100%|██████████| 2496/2496 [00:16<00:00, 150.01it/s]
# 100%|██████████| 1483/1483 [00:00<00:00, 31102.16it/s]
# Successful generations: 1483
# Uniqness score: 0.9991766548010568
# ====================== Chain size: 4 ======================
# 100%|██████████| 2496/2496 [00:45<00:00, 55.18it/s]
# 100%|██████████| 1071/1071 [00:00<00:00, 30908.16it/s]
# Successful generations: 1071
# Uniqness score: 0.9959202130340875
# ====================== Chain size: 5 ======================
# 100%|██████████| 2496/2496 [01:04<00:00, 38.81it/s]
# 100%|██████████| 279/279 [00:00<00:00, 41766.39it/s]
# Successful generations: 279
# Uniqness score: 0.9939975485222575

# %%
model_size = 5

for result, reference in zip(results[model_size], references[model_size]):
    print("===================================================================================================")
    print(f"Reference: {reference}\nGenerated: {result}")
    print(f"Uniqness score: {get_uniqness_measure(result) / get_uniqness_measure(ref)}")
    print("measure result:", get_uniqness_measure(result))
    print("measure reference:", get_uniqness_measure(ref))
# Out:
# ===================================================================================================
# Reference: There was another burst of song, and then suddenly, hopping and dancing along the path, there appeared above the reeds an old battered hat with a tall crown and a long blue feather stuck in the band.
# Generated: There was another smaller door on the other side of the hearth he heard Bilbo's voice speaking.
# Uniqness score: 1.0024038461538463
# measure result: 0.9230769230769231
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: When Sam got back he found the whole village roused.
# Generated: When Sam awoke, he found that he was trembling. said Legolas.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a wide arch leading to a courtyard between the two wings, and on the left under the arch there was a large doorway reached by a few broad steps.
# Generated: There was a pale figure hurrying away in and out of the shadows on the other side of the mountains.
# Uniqness score: 1.028782894736842
# measure result: 0.9473684210526315
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They spoke aloud, and cried out to one another, as they lifted old treasures from the mound or from the wall and held them in the light caressing and fingering them.
# Generated: They spoke together, and then suddenly it seemed to Frodo that he looked upon a morning of sudden hope.
# Uniqness score: 1.053030303030303
# measure result: 0.9696969696969697
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And they were my kindred and my friends.
# Generated: And they fled before the wrath of Isildur, and did not dare to go near enough to the wizard to reach the bundle.
# Uniqness score: 1.0557725694444444
# measure result: 0.9722222222222222
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There is Hasufel, and there is my friend Arod beside him!
# Generated: There is a lot more in him than you guess, and you will find that out before long.
# Uniqness score: 1.0720152243589745
# measure result: 0.9871794871794872
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But as that comes in at the end of this tale we will say no more about it just now.
# Generated: But as they drew near to the borders of the Road.
# Uniqness score: 1.0618055555555554
# measure result: 0.9777777777777777
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Merry and Pippin began a song, which they had apparently got ready for the occasion.
# Generated: Merry and Fatty went into the kitchen on the other side of the hearth he heard Bilbo's voice speaking.
# Uniqness score: 1.030532525510204
# measure result: 0.9489795918367347
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Soon they could hear even the flap of the goblin feet, many many feet which seemed only just round the last corner.
# Generated: Soon they all stood once more on the flat shelf at the head of the valley, and another round the northern wall.
# Uniqness score: 1.0351927570093458
# measure result: 0.9532710280373832
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And far away, its dark head in a torn cloud, there loomed the Mountain!
# Generated: And far away, as Frodo put on the Ring and seen Shagrat's company go by.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a hurrying sound of many feet.
# Generated: There was a great shadowy wood of Huorns at the head of the sin ng company with beating hearts and heads held high.
# Uniqness score: 1.056587837837838
# measure result: 0.972972972972973
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was chilly, and he wrapped his cloak about him.
# Generated: It was already night when at last they halted and dismounted, even Aragorn was stiff and weary.
# Uniqness score: 1.0620707417582416
# measure result: 0.978021978021978
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The sword of Aragorn, stiff in his motionless hand, blazed with a sudden fire.
# Generated: The sword rang faintly, and glinted a little in the light of the stars, which were already shining in the sky.
# Uniqness score: 1.0244693396226414
# measure result: 0.9433962264150944
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And suddenly there rose a great chorus of trumpets from high above, sounding from some hollow place, as it seemed, that gathered their notes into one voice and sent it rolling and beating on the walls of stone.
# Generated: And suddenly he saw that he was in the midst of a pool.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then they rested and slept without fear upon the ground; for their guides would not permit them to unbind their eyes, and they could not climb.
# Generated: Then they knew that Gandalf was going to leave them at the very edge of the wood more prints were discovered.
# Uniqness score: 1.075595238095238
# measure result: 0.9904761904761905
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They were in a deep lane between the ends of the wall, and passing quickly through it they entered the City of the Trees.
# Generated: They were sick and weary, and they could not go much further, if the snow continued.
# Uniqness score: 1.07236328125
# measure result: 0.9875
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I have never seen or heard tell of one so fair.
# Generated: I have told you before that he has more about him than you guess, and a deal more than he has any idea of himself.
# Uniqness score: 0.9674715909090909
# measure result: 0.8909090909090909
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was not a cave and was open to the sky above; but at its inner end a flat wall rose up that in the lower I part, close to the ground, was as smooth and upright as mason's work, but without a joint or crevice to be seen.
# Generated: It was already night when at last they halted and dismounted, even Aragorn was stiff and weary.
# Uniqness score: 1.0620707417582416
# measure result: 0.978021978021978
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But the portcullis was often open, for a good deal of traffic went out and in by the water-gate.
# Generated: But the marks might mean something quite different, and have nothing to do with us at all, we must go down at once.
# Uniqness score: 1.0663710585585584
# measure result: 0.9819819819819819
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Most of their earlier settlements had long disappeared and been forgotten in Bilbo's time; but one of the first to become important still endured, though reduced in size; this was at Bree and in the Chetwood that lay round about, some forty miles east of the Shire.
# Generated: Most of the time they sat silent under the shelter of the cliff, until he came back.
# Uniqness score: 1.01806640625
# measure result: 0.9375
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last Frodo spoke with hesitation.
# Generated: At last Haldir led them down the southward slopes of the hill, and came in a little while to the edge of the wood.
# Uniqness score: 1.0267045454545454
# measure result: 0.9454545454545454
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then he went and sat by himself a few paces away and whimpered a little.
# Generated: Then he climbed to the top of the southern bank above the pool.
# Uniqness score: 1.0491260593220337
# measure result: 0.9661016949152542
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Far away down in the Bay of Belfalas, to which Anduin runs, it is warm and merry, maybe, or would be but for the Enemy.
# Generated: Far away in the tumble of country that lay at the foot of the terrace and in his helm drew water.
# Uniqness score: 1.050907258064516
# measure result: 0.967741935483871
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then he glanced up at the great cliff rising up, away on their left.
# Generated: Then he ran to the place where he had stood before, he threw some more stones and stamped.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He was wrong.
# Generated: He was glad, though he felt that it was too much to hope that the Riders had already lost their trail again.
# Uniqness score: 1.0441706730769231
# measure result: 0.9615384615384616
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I am ten years a lready, and shall soon be five feet.
# Generated: I am getting very old, and I began to wonder if even your luck would see you through!
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a terrific splash, and a shout of Whoa! from Frodo.
# Generated: There was Gandalf as chief herald, and Aragorn with the sons of Elrond, and together they laboured far into the night.
# Uniqness score: 1.0478344298245614
# measure result: 0.9649122807017544
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: So he let Merry sink gently down on to the pavement in a patch of sunlight, and then he sat down beside him, laying Merry's head in his lap.
# Generated: So he sat himself down with his back to a great tree, as if he was resting.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There he lay for a while, fighting with despair.
# Generated: There he was calmly sitting in a chair by the open window. he cried.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I am afraid we shall have to try to get one pony at least.
# Generated: I am Merry Brandybuck, and I should like to know where it is, if you go wandering again.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a strange look in his eyes of mingled wonder and respect and hatred.
# Generated: There was a beaten way, north-westward along the foot-hills of the White Mountains, and crossed the Isen and the Greyflood into Northerland.
# Uniqness score: 1.0460133272058822
# measure result: 0.9632352941176471
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But we are envying Sam, not you.
# Generated: But we must go on; and it is no good waiting for him. said he.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a ring and clash of steel.
# Generated: There was some murmuring, but also some grins on the faces of the sick and seen their hurts he sighed.
# Uniqness score: 1.030532525510204
# measure result: 0.9489795918367347
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was among them a family of high repute, for it was large and wealthier than most, and it was ruled by a grandmother of the folk, stern and wise in old lore, such as they had.
# Generated: There was almost silence, and one or two of the songs that they heard in that house.
# Uniqness score: 1.0587890624999998
# measure result: 0.975
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He would cackle with laughter and caper, if any jest was made, or even if Frodo spoke kindly to him, and weep if Frodo rebuked him.
# Generated: He would have burst out of the trees and come careering down the slope.
# Uniqness score: 1.0697294776119401
# measure result: 0.9850746268656716
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was not very long, though fear made it seem an hour at least, before he heard Sam's voice calling softly from below: Elbereth, Elbereth . Frodo let down the light ladder.
# Generated: It was near ####-the end of the second day of their riding drew on, the heaviness in the air increased.
# Uniqness score: 1.0310921717171717
# measure result: 0.9494949494949495
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: A little way back above the lake they found a deep brown bed of last year's fern.
# Generated: A little black head appeared at the far end of the cavern with little Bilbo tugging at the end of the mountains: Nan Curunnr, the Valley of Saruman.
# Uniqness score: 0.9501953125
# measure result: 0.875
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: A great black shape against the fires beyond he loomed up, grown to a vast menace of despair.
# Generated: A great cloud of it was going up far away in the direction of the voice. said Strider quickly, and with surprising earnestness.
# Uniqness score: 1.0771087398373982
# measure result: 0.991869918699187
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then they came to lands where people spoke strangely, and sang songs Bilbo had never heard before.
# Generated: Then they knew that Gandalf was going to leave them at the very edge of the wood more prints were discovered.
# Uniqness score: 1.075595238095238
# measure result: 0.9904761904761905
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was after nightfall when they had entered the Mines.
# Generated: It was near ####-the end of the second day of their riding drew on, the heaviness in the air increased.
# Uniqness score: 1.0310921717171717
# measure result: 0.9494949494949495
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At that old Ghvn made a curious gurgling noise, and it seemed that he was laughing.
# Generated: At that moment Sam came running back from the edge of the wood, there was a mound.
# Uniqness score: 1.0720152243589745
# measure result: 0.9871794871794872
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The air was cool and soft, as if it were early spring, yet they felt about them the deep and thoughtful quiet of winter.
# Generated: The air was gleaming and sunlit, but hazy; and they could not see any glimpse of the lands behind.
# Uniqness score: 1.0743849734042552
# measure result: 0.9893617021276596
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was victory and defeat; and towers fell, fortresses were burned, and flames went up into the sky.
# Generated: There was Gandalf as chief herald, and Aragorn with the sons of Elrond, and together they laboured far into the night.
# Uniqness score: 1.0478344298245614
# measure result: 0.9649122807017544
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They spoke of the Halfling.
# Generated: They spoke together, and then suddenly it seemed to Frodo that he looked upon a morning of sudden hope.
# Uniqness score: 1.053030303030303
# measure result: 0.9696969696969697
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a mighty pushing of poles.
# Generated: There was almost silence, and one or two of the songs that they heard in that house.
# Uniqness score: 1.0587890624999998
# measure result: 0.975
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: A great stone table stood there, but no chairs.
# Generated: A great cloud of it was going up far away in the direction of the call, and found himself going steeply uphill.
# Uniqness score: 1.0453417056074765
# measure result: 0.9626168224299065
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He was out of breath.
# Generated: He was sitting, black in the moonlight, on the top of a high bank above the Road.
# Uniqness score: 1.0436282467532467
# measure result: 0.961038961038961
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He did what was probably the best thing he could have done.
# Generated: He did not at all like the look of the Riders, and would certainly be frightened by them.
# Uniqness score: 1.0731617647058824
# measure result: 0.9882352941176471
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There they sat for a long while and did not dare to make a move.
# Generated: There they had gathered in the shadow of the hills there had been some rain.
# Uniqness score: 1.0256076388888888
# measure result: 0.9444444444444444
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was close on midnight, and they had been drifting for some while. hardly using the paddles, when suddenly Sam cried out.
# Generated: It was already night when at last they halted and dismounted, even Aragorn was stiff and weary.
# Uniqness score: 1.0620707417582416
# measure result: 0.978021978021978
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He was as noble and as fair in face as an elf-lord, as strong as a warrior, as wise as a wizard, as venerable as a king of dwarves, and as kind as summer.
# Generated: He was coming to the top of the southern bank above the pool.
# Uniqness score: 1.0478344298245614
# measure result: 0.9649122807017544
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And he was right there too.
# Generated: And he will tell you that he did not know in what direction to turn.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He sat up painfully.
# Generated: He sat down on the bank at the side of the Road, while he went forward to explore.
# Uniqness score: 1.0580929487179487
# measure result: 0.9743589743589743
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The light was nearly gone, and they were all exhausted, when at last they reached the top.
# Generated: The light of the shaft fell directly on a table in the middle of the floor of a large round chamber.
# Uniqness score: 1.0293782552083333
# measure result: 0.9479166666666666
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But he did not speak long with you.
# Generated: But he soon made up his mind that it was no good giving up their quest yet.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I am a hobbit and no more valiant than I am a man, save perhaps now and again by necessity.
# Generated: I am getting very old, and I began to wonder if even your luck would see you through!
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: So they got a black pot, and they took out their knives.
# Generated: So they sang, or very like that, only there was a great deal better cheer that Yule than anyone had hoped for.
# Uniqness score: 1.065448113207547
# measure result: 0.9811320754716981
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He sat for a moment half dreaming, listening to the noise of water, the whisper of dark trees, the crack of stone, and the vast waiting silence that brooded behind all sound.
# Generated: He sat down on the bank at the side of the Road, while he went forward to explore.
# Uniqness score: 1.0580929487179487
# measure result: 0.9743589743589743
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He went off at dawn.
# Generated: He went on again, but his uneasiness grew, and every now and again a black and ominous crow.
# Uniqness score: 1.0365767045454546
# measure result: 0.9545454545454546
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last they could go no further without a halt.
# Generated: At last one, a tall young fellow, came out from the trees and ####-rocks away on the left four other Riders came flying.
# Uniqness score: 1.0578529094827587
# measure result: 0.9741379310344828
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: So they spread out their wet things on the floor, and got dry ones out of their bundles; then they made their blankets comfortable, got out their pipes and blew smoke rings, which Gandalf turned into different colours and set dancing up by the roof to amuse them.
# Generated: So they sang, or very like that, only there was a great deal better cheer that Yule than anyone had hoped for.
# Uniqness score: 1.065448113207547
# measure result: 0.9811320754716981
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last they turned away and faded silently into the dusk.
# Generated: At last one, a tall young fellow, came out from the trees and ####-rocks away on the left four other Riders came flying.
# Uniqness score: 1.0578529094827587
# measure result: 0.9741379310344828
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There he halted only a short while and strengthened his host by some three score of Riders that came late to the weapontake.
# Generated: There he was calmly sitting in a chair by the open window. he cried.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He could not catch them up.
# Generated: He could not be quite sure, but it seemed to him that it flickered red, as if it was a firebrand.
# Uniqness score: 1.074260752688172
# measure result: 0.989247311827957
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The air grew warm and very still under the great moist clouds that had floated up from the South and the distant seas.
# Generated: The air was gleaming and sunlit, but hazy; and they could not see any glimpse of the lands behind.
# Uniqness score: 1.0743849734042552
# measure result: 0.9893617021276596
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Most of them are in it against their will, but not all.
# Generated: Most of the time they sat silent under the shelter of the cliff, until he came back.
# Uniqness score: 1.01806640625
# measure result: 0.9375
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last the snow stopped altogether.
# Generated: At last one, a tall young fellow, came out from the trees and ####-rocks away on the left four other Riders came flying.
# Uniqness score: 1.0578529094827587
# measure result: 0.9741379310344828
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: You are wise, maybe, Mithrandir, yet with all your subtleties you have not all wisdom.
# Generated: You are familiar with Thorin's style on important occasions, so I will not give you counsel, saying do this, or do that.
# Uniqness score: 1.0672144396551724
# measure result: 0.9827586206896551
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The air was filled with circling flocks, and their swift-flying messengers flew here and there across the sky.
# Generated: The air was gleaming and sunlit, but hazy; and they could not see any glimpse of the lands behind.
# Uniqness score: 1.0743849734042552
# measure result: 0.9893617021276596
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He had a half-eaten fish in his mouth and another in his hand.
# Generated: He had not boats or rafts enough for his host, and they were forced to turn away northwards out of their ####-course.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last she spoke again.
# Generated: At last one, a tall young fellow, came out from the trees and walked towards them without speaking.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At the moment the noise seemed to be coming from the court behind the outer wall.
# Generated: At the far end of the cavern with little Bilbo tugging at the end of the lake and came into the desolate lands.
# Uniqness score: 0.9641501168224298
# measure result: 0.8878504672897196
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And then a trumpet rang from the Citadel, and Denethor at last released the sortie.
# Generated: And then it seemed to him that it flickered red, as if it was a chasm in the mountains.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was the right hand, and the third finger was missing.
# Generated: It was near ####-the end of the second day of their riding drew on, the heaviness in the air increased.
# Uniqness score: 1.0310921717171717
# measure result: 0.9494949494949495
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: In the old days hobbits used to go on their travels now and again.
# Generated: In the late afternoon they came to a place where the trees on either hand grew thinner.
# Uniqness score: 1.0597703313253013
# measure result: 0.9759036144578314
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was loud and long applause.
# Generated: There was Gandalf as chief herald, and Aragorn with the sons of Elrond, and together they laboured far into the night.
# Uniqness score: 1.0478344298245614
# measure result: 0.9649122807017544
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But there seemed small need for watching in the days of our prosperity, and the guards were made over comfortable, perhaps – otherwise we might have had longer warnings of the coming of the dragon, and things might have been different.
# Generated: But there were still five dwarves hanging at the end of the mountains: Nan Curunnr, the Valley of Saruman.
# Uniqness score: 1.0539981617647058
# measure result: 0.9705882352941176
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a silence.
# Generated: There was a great shadowy wood of Huorns at the head of the sin ng company with beating hearts and heads held high.
# Uniqness score: 1.056587837837838
# measure result: 0.972972972972973
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And with that he raced round the last corner, only to find that by some trick of the tunnel, or of the hearing which the Ring gave him, he had misjudged the distance.
# Generated: And with that he sat down beside Frodo under the shadow of the Hornburg lay Hbma, captain of the King's guard.
# Uniqness score: 1.0347140330188678
# measure result: 0.9528301886792453
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I have thought of a nice ending for it: and he lived happily ever after to the end of his days.
# Generated: I have no duty this morning, and I have been sent to look here for the last time.
# Uniqness score: 1.0436282467532467
# measure result: 0.961038961038961
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He drew himself up and stared at them darkly with his black eyes.
# Generated: He drew himself up and looked back at the way they had ####-come.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The ponies had vanished!
# Generated: The ponies they had brought only to the head of the fall over which the stream went towards Dale.
# Uniqness score: 1.062584005376344
# measure result: 0.978494623655914
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was the third evening since they had fled from the Company, as far as they could tell: they had almost lost count of the hours during which they had climbed and laboured among the barren slopes and stones of the Emyn Muil, sometimes retracing their steps because they could find no way forward, sometimes discovering that they had wandered in a circle back to where they had been hours before.
# Generated: It was near ####-the end of the second day of their riding drew on, the heaviness in the air increased.
# Uniqness score: 1.0310921717171717
# measure result: 0.9494949494949495
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There he found all the others sitting with their backs to the mountain wall.
# Generated: There he was calmly sitting in a chair by the open window. he cried.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was also a strange Elf clad in green and brown, Legolas, a messenger from his father, Thranduil, the King of the Elves of Northern Mirkwood.
# Generated: There was a great deal in the background of their memories; but it was ominous and disquieting.
# Uniqness score: 1.074004120879121
# measure result: 0.989010989010989
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Already they heard below them in the town the heralds crying and the war -horns blowing.
# Generated: Already they I seemed only a day's easy journey from the feet of the cliffs near where the doors had stood.
# Uniqness score: 1.0648513349514563
# measure result: 0.9805825242718447
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was some sense at any rate in keeping a guard, while ruffians were still about.
# Generated: There was Gandalf as chief herald, and Aragorn with the sons of Elrond, and together they laboured far into the night.
# Uniqness score: 1.0478344298245614
# measure result: 0.9649122807017544
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He had hardly sat down, when there came a soft knock at the front-door.
# Generated: He had not boats or rafts enough for his host, and they were forced to turn away northwards out of their ####-course.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: A mile southwards along the shore they came upon holly trees.
# Generated: A mile further on they came to a narrow opening shrouded with thick bushes.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a tearing creak and the other crack split open, and out of it Pippin sprang, as if he had been kicked.
# Generated: There was almost silence, and one or two of the songs that they heard in that house.
# Uniqness score: 1.0587890624999998
# measure result: 0.975
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then they saw him halt and stoop for a moment; but they did not know the reason.
# Generated: Then they knew that Gandalf was going to leave them at the very edge of the wood more prints were discovered.
# Uniqness score: 1.075595238095238
# measure result: 0.9904761904761905
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They were now silent, and as the last Elf passed he turned and looked towards the hobbits and laughed.
# Generated: They were sick and weary, and they could not go much further, if the snow continued.
# Uniqness score: 1.07236328125
# measure result: 0.9875
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a noise in the night like a wind coming up the valley.
# Generated: There was Gandalf as chief herald, and Aragorn with the sons of Elrond, and together they laboured far into the night.
# Uniqness score: 1.0478344298245614
# measure result: 0.9649122807017544
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But we have suffered much loss in our battles with Saruman the traitor, and we must still think of our frontier to the north and east, as his own tidings make clear.
# Generated: But we must go on; and it is no good waiting for him. said he.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was gone.
# Generated: It was near ####-the end of the second day of their riding drew on, the heaviness in the air increased.
# Uniqness score: 1.0310921717171717
# measure result: 0.9494949494949495
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: In a minute they would reach the top and be on him.
# Generated: In a chair, at the far side of the tree from the prisoners.
# Uniqness score: 1.0464488636363636
# measure result: 0.9636363636363636
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He could not speak.
# Generated: He could not be quite sure, but it seemed to him that they would break his heart with joy.
# Uniqness score: 1.0733103197674418
# measure result: 0.9883720930232558
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Pippin saw him go to Merry, who was lying close by, and kick him.
# Generated: Pippin saw then that they had been standing in alcoves on either side of the gate through which the glare ####-of Mordor dimly showed.
# Uniqness score: 1.0692307692307692
# measure result: 0.9846153846153847
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They were still standing over him, cursing their ill luck, and Bombur's clumsiness, and lamenting the loss of the boat which made it impossible for them to go back and look for the hart, when they became aware of the dim blowing of horns in the wood and the sound as of dogs baying far off.
# Generated: They were sick and weary, and they could not go much further, if the snow continued.
# Uniqness score: 1.07236328125
# measure result: 0.9875
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Gandalf stood up and strode forward, holding his staff aloft.
# Generated: Gandalf stood in the middle of the kitchen trying to see what they were up to, and to prevent them from trespassing.
# Uniqness score: 1.0665457589285714
# measure result: 0.9821428571428571
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They came at last to a white bridge, and crossing found the great gates of the city: they faced south-west, set between the ends of the encircling wall that here overlapped, and they were tall and strong, and hung with many lamps.
# Generated: They came to the edge of the Road.
# Uniqness score: 1.0497395833333334
# measure result: 0.9666666666666667
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And so Merry was sent to Faramir, and while that day lasted they talked long together, and Faramir learned much, more even than Merry put into words; and he thought that he understood now something of the grief and unrest of Jowyn of Rohan.
# Generated: And so at length Jomer and Aragorn met in the midst of the glory of the king his golden shield was dimmed.
# Uniqness score: 1.032705269607843
# measure result: 0.9509803921568627
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He stood up, and it looked to Sam as if he was clothed in flame: his naked skin was scarlet in the light of the lamp above.
# Generated: He stood still listening for a little hoping perhaps to learn something that would help them to understand their hurts.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was no sound.
# Generated: There was a flat space on the top of the mountains, and go home?
# Uniqness score: 1.0678385416666665
# measure result: 0.9833333333333333
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At length they stirred and looked up, and began to search for anything that would give them tidings of Balin's fate, or show what had become of his folk.
# Generated: At length they reached the trees, and found that they had come to the bottom of the gully again.
# Uniqness score: 1.0387228260869565
# measure result: 0.9565217391304348
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a faint stir in the leaves, and a cock crowed far away.
# Generated: There was almost silence, and one or two of the songs that they heard in that house.
# Uniqness score: 1.0587890624999998
# measure result: 0.975
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And with that Ya hoy!
# Generated: And with that he sat down beside Frodo under the shadow of the rock and waited for them.
# Uniqness score: 1.0600818452380951
# measure result: 0.9761904761904762
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He knew the story well.
# Generated: He knew many histories and legends of long ago, of Elves and Men and all Free Folk go with you.
# Uniqness score: 1.0382039835164836
# measure result: 0.9560439560439561
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last the hobbits saw, rising dimly before them, a steep dark land: they had come to the feet of the mountains, and to the green roots of tall Methedras.
# Generated: At last one, a tall young fellow, came out from the trees and ####-rocks away on the left four other Riders came flying.
# Uniqness score: 1.0578529094827587
# measure result: 0.9741379310344828
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But you have to eat some of it every day, and it doesn't grow.
# Generated: But you comfort me, Gimli, and I am glad to have heard you speak so fully.
# Uniqness score: 1.070424107142857
# measure result: 0.9857142857142858
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But the hobbits came and cut down hundreds of trees, and made a great bonfire in the Forest, and burned all the ground in a long strip east of the Hedge.
# Generated: But the marks might mean something quite different, and have nothing to do with us at all, we must go down at once.
# Uniqness score: 1.0663710585585584
# measure result: 0.9819819819819819
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They could hear the giants guffawing and shouting all over the mountainsides.
# Generated: They could not find Bilbo with the ring on, slipping in and out of the shadows on the other side of the world.
# Uniqness score: 1.0244693396226414
# measure result: 0.9433962264150944
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He drew out his swor d, and they saw that the blade was indeed broken a foot below the hilt.
# Generated: He drew himself up and looked back at the way they had ####-come.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And as if in answer there came from far away another note.
# Generated: And as he watched, it seemed to him that it flickered red, as if it was a chasm in the mountains.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was now past mid-day, and they felt it was high time for lunch.
# Generated: It was never an Entish song, mark you: it would have been a heavy blow to us, and it might have been fatal.
# Uniqness score: 1.012135922330097
# measure result: 0.9320388349514563
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He was covered with green slime.
# Generated: He was already far away, leaping blindly up the path to the top of the bank, with a broken sword under you.
# Uniqness score: 1.0648513349514563
# measure result: 0.9805825242718447
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: A little below him to the left the road ran down steeply into a hollow and disappeared.
# ...
# Generated: He knew many histories and legends of long ago, of Elves and Men and all Free Folk go with you.
# Uniqness score: 1.0382039835164836
# measure result: 0.9560439560439561
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: As they were swept aside the travellers could see, now very close, the pale foam of the River lashing against sharp rocks that were thrust out far into the stream like a ridge of teeth.
# Generated: As they went on Bilbo looked from side to side for something which he could not find.
# Uniqness score: 1.0591242283950617
# measure result: 0.9753086419753086
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: You are still some miles north of the path which we should have been following, if we had not left the mountain pass in a hurry.
# Generated: You are familiar with Thorin's style on important occasions, so I will not give you counsel, saying do this, or do that.
# Uniqness score: 1.0672144396551724
# measure result: 0.9827586206896551
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The three hobbits came on, and then the ruffians turned and fled running away up the Hobbiton Road; but they blew their horns as they ran.
# Generated: The three Riders that were still in the midst of the leading company, his household-men about him.
# Uniqness score: 1.0743849734042552
# measure result: 0.9893617021276596
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: The land all about was dreary, flat and drab-hued.
# Generated: The land began to slope up and up, and it seemed to him that Boromir was alive again and had returned. cried Frodo.
# Uniqness score: 1.0663710585585584
# measure result: 0.9819819819819819
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But the Mirror will also show things unbidden, and those are often stranger and more profitable than things which we wish to behold.
# Generated: But the tracker, springing behind a stone, put an arrow in his eye as he thought of the long and painful march downhill.
# Uniqness score: 1.0765759698275863
# measure result: 0.9913793103448276
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But there are few left in Middle-earth like Aragorn son of Arathorn.
# Generated: But there were still five dwarves hanging at the end of the lake and came into the desolate lands.
# Uniqness score: 1.0512799202127658
# measure result: 0.9680851063829787
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Soon they came to places where, as Bilbo had noticed on the way down, side-passages opened, this way and that.
# Generated: Soon they were falling over one another and getting very angry.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last with an effort he spoke, and wondered to hear his own words, as if some other will was using his small voice.
# Generated: At last one, a tall young fellow, came out from the trees and walked towards them without speaking.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was a wide treeless space before them, running in a great circle and bending away on either hand.
# Generated: There was a flat space on the top of the southern bank above the pool.
# Uniqness score: 1.053030303030303
# measure result: 0.9696969696969697
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: At last the three companions turned away, and never again looking back they rode slowly homewards; and they spoke no word to one another until they came back to the Shire. but each had great comfort in his friends on the long grey road.
# Generated: At last one, a tall young fellow, came out from the trees and ####-rocks away on the left four other Riders came flying.
# Uniqness score: 1.0578529094827587
# measure result: 0.9741379310344828
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Now they bid me climb up with Frodo; for they seem to have had some tidings of him and of our journey.
# Generated: Now they laid Boromir in the middle of the kitchen trying to see what they were up to, and to prevent them from trespassing.
# Uniqness score: 1.0497395833333334
# measure result: 0.9666666666666667
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But when the dawn came, cold and pale, Aragorn rose at once, and he led the Company forth upon the journey of greatest haste and weariness that any among them had known, save he alone, and only his will held them to go on.
# Generated: But when they had come almost to the end of the search when the day began to fail.
# Uniqness score: 0.9884815705128205
# measure result: 0.9102564102564102
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: But there was so much at stake that I had to take some risk - though even when I was far away there has never been a day when the Shire has not been guarded by watchful eyes.
# Generated: But there was no sign of the Riders.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I am afraid of the pool.
# Generated: I am getting very old, and I began to wonder if even your luck would see you through!
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He was to have come to Hobbiton at the latest two nights ago; but he has never appeared.
# Generated: He was glad, though he felt that it was too much to hope that the Riders had already lost their trail again.
# Uniqness score: 1.0441706730769231
# measure result: 0.9615384615384616
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Not far away the voices of the Entmoot could be heard still going on; but now they seemed deeper and less leisurely, and every now and again one great voice would rise in a high and quickening music, while all the others died away.
# Generated: Not far away was his island, of which Bilbo knew nothing, not far off in the dark water.
# Uniqness score: 1.0471540178571428
# measure result: 0.9642857142857143
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He hissed and spluttered and rocked himself backwards and forwards, and slapped his feet on the floor, and wriggled and squirmed; but still he did not dare to waste his last guess.
# Generated: He hissed to himself, and still he did not come, or send word.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then suddenly one of the slave-drivers spied the two figures by the road-side.
# Generated: Then suddenly he slopped, and they saw that he carried a great cudgel.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then suddenly she laid her hand on his arm.
# Generated: Then suddenly he slopped, and they saw that he carried a great cudgel.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: All the East is moving.
# Generated: All the wall gave way, and the roof of the Great House crumbled and smashed down.
# Uniqness score: 1.0436282467532467
# measure result: 0.961038961038961
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I have heard songs of many battles, and I have always understood that defeat may be glorious.
# Generated: I have told you before that he has more about him than you guess, and a deal more than he has any idea of himself.
# Uniqness score: 0.9674715909090909
# measure result: 0.8909090909090909
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Merry looked round in dismay and disgust.
# Generated: Merry looked up and saw that it was a grey-hooded Elf.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He was riding a pony, and a scarf was swathed round his neck and over his chin to keep out the fog.
# Generated: He was sitting, black in the moonlight, on the top of a high bank above the Road.
# Uniqness score: 1.0436282467532467
# measure result: 0.961038961038961
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: It was burned and broken, and nothing remains of it now but a tumbled ring, like a rough crown on the old hill's head.
# Generated: It was never an Entish song, mark you: it would have been a heavy blow to us, and it might have been fatal.
# Uniqness score: 1.012135922330097
# measure result: 0.9320388349514563
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: He had a feeling that the answer was quite different and that he ought to know it, but he could not think of it.
# Generated: He had not boats or rafts enough for his host, and they were forced to turn away northwards out of their ####-course.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I have wandered for some time since.
# Generated: I have often kept watch on the borders of the Desolation of the Dragon.
# Uniqness score: 0.9886893656716417
# measure result: 0.9104477611940298
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I have no signs on my door-it was painted a week ago-, and I am quite sure you have come to the wrong house.
# Generated: I have told you before that he has more about him than you guess, and a deal more than he has any idea of himself.
# Uniqness score: 0.9674715909090909
# measure result: 0.8909090909090909
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There is no water and no shelter.
# Generated: There is a lot more in him than you guess, and you will find that out before long.
# Uniqness score: 1.0720152243589745
# measure result: 0.9871794871794872
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And they clasped hand in hand.
# Generated: And they fled before the wrath of Isildur, and did not dare to go near enough to the wizard to reach the bundle.
# Uniqness score: 1.0557725694444444
# measure result: 0.9722222222222222
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: And when he said gollum he made a horrible swallowing noise in his throat.
# Generated: And when he could labour no more, he cast his cloak about him again, and went from the walls.
# Uniqness score: 1.0737359550561796
# measure result: 0.9887640449438202
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: For the old man died in that hour and fell upon his face; and no other tidings of the ancient dwellers in the mountains have our folk ever learned.
# Generated: For the world is changing: I feel it in the earth, and I smell it in the air.
# Uniqness score: 0.9520547945205479
# measure result: 0.8767123287671232
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: I am leaving NOW.
# Generated: I am getting very old, and I began to wonder if even your luck would see you through!
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: There was no undergrowth.
# Generated: There was Gandalf as chief herald, and Aragorn with the sons of Elrond, and together they laboured far into the night.
# Uniqness score: 1.0478344298245614
# measure result: 0.9649122807017544
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: You are the fool, going on hoping and toiling.
# Generated: You are familiar with Thorin's style on important occasions, so I will not give you counsel, saying do this, or do that.
# Uniqness score: 1.0672144396551724
# measure result: 0.9827586206896551
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Then he gave a low gasp, for the stars went out.
# Generated: Then he climbed to the top of a large rock.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They were more than weary, and yet there seemed no comfort in the thought of halting anywhere.
# Generated: They were in a long low room, filled with the light of the moon above the rim of Earth.
# Uniqness score: 1.0597703313253013
# measure result: 0.9759036144578314
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: Soon they were leading their ponies in single file over the rim and down the long northward slope of the hill, down into a foggy sea.
# Generated: Soon they were falling over one another and getting very angry.
# Uniqness score: 1.0859375
# measure result: 1.0
# measure reference: 0.920863309352518
# ===================================================================================================
# Reference: They came to the river that marked the very edge of the borderland of the Wild, and to the ford beneath the steep bank, which you may remember.
# Generated: They came at length to the edge of the fire and the light faded as if a cloud had been withdrawn.
# Uniqness score: 1.062584005376344
# measure result: 0.978494623655914
# measure reference: 0.920863309352518
